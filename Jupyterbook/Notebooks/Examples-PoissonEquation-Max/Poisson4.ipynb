# %%
#!/usr/bin/env python
# coding: utf-8

# %% [markdown]
# # Solving the Poisson Equation in underworld 3 (Part 4)<br>
# <br>
# This notebook shows how to solve the non-linear Poisson equation $\nabla \cdot (k \nabla \phi) = S$ for a $k$ as a function of the field $\phi$ and non-zero source term $S$ with Dirichlet boundary conditions in a 2-Dimensional annulus.

# %%
import underworld3 as uw  ## import underworld
from mpi4py import MPI  ## library for displaying
import sympy  ## for generating symbolic expressions

# %% [markdown]
# We solve $\nabla \cdot ((1 + \phi) \nabla \phi) = 4 + 8 x^2 + 8 y^2$ on an annulus with inner radius $0.1$ and outer radius $1$ with boundary conditions of $\phi=0.1$ on the inner boundary and $\phi=1$ on the outer boundary. Unlike the Cartesian examples Poisson[1-4].ipyn, we use an annulus as our domain. Underworld 3 features other geometries - see [here](https://underworldcode.github.io/underworld3/development_api/meshing.html) for more.

# %%
mesh = uw.meshing.Annulus(radiusInner=0.1, radiusOuter=1, cellSize=0.025, qdegree=5)

# %% [markdown]
# Like the Cartesian meshes, we can access the coordinates of the mesh using the X method.

# %%
mesh.X
# Out:
# Matrix([[N.x, N.y]])

# %% [markdown]
# The coordinates here are still Cartesian x, y. As in Poisson[1-3].ipynb, we set our solver, source, constitutive model, and boundary conditions.

# %% [markdown]
#  define our scalar variable phi

# %%
phi = uw.discretisation.MeshVariable(r"\phi", mesh, 1, degree=3)

# %% [markdown]
#  define the Poisson solver

# %%
poisson_solver = uw.systems.Poisson(mesh, phi)

# %% [markdown]
#  set the source term

# %%
x, y = mesh.X 
source_fn = 4 + 8 * x**2 + 8 * y**2
poisson_solver.f = -source_fn

# %% [markdown]
#  set the diffusive model

# %%
poisson_solver.constitutive_model = uw.systems.constitutive_models.DiffusionModel(mesh.dim)

# %% [markdown]
#  boundary conditions

# %%
bottomCondition = 0.01
topCondition = 1
poisson_solver.add_dirichlet_bc((bottomCondition,), "Lower", (0,))
poisson_solver.add_dirichlet_bc((topCondition,), "Upper", (0,))

# %% [markdown]
# We slowly introduce non-linearity as in Poisson3.ipynb to avoid divergence in the solver.

# %% [markdown]
#  get the symbolic representation of the diffusivity

# %%
k_fn = 1 + phi.sym[0]

# %%
aList = [1 - da/10 for da in range(11)]
for a in aList:
    poisson_solver.constitutive_model.Parameters.diffusivity = a + (1 - a) * k_fn
    poisson_solver.solve()
# Out:
#   0 SNES Function norm 58.1252
#   1 SNES Function norm 0.00971717
#   2 SNES Function norm 1.22987e-07
# Nonlinear Poisson_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 2
#   0 SNES Function norm 62.037
#   1 SNES Function norm 2.11873
#   2 SNES Function norm 0.00340089
# Nonlinear Poisson_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 2
#   0 SNES Function norm 65.9529
#   1 SNES Function norm 4.50428
#   2 SNES Function norm 0.0274241
#   3 SNES Function norm 5.18594e-06
# Nonlinear Poisson_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 3
#   0 SNES Function norm 69.8722
#   1 SNES Function norm 7.15179
#   2 SNES Function norm 0.0930804
#   3 SNES Function norm 4.67607e-05
# Nonlinear Poisson_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 3
#   0 SNES Function norm 73.7944
#   1 SNES Function norm 10.0608
#   2 SNES Function norm 0.221197
#   3 SNES Function norm 0.000291207
# Nonlinear Poisson_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 3
#   0 SNES Function norm 77.7191
#   1 SNES Function norm 13.237
#   2 SNES Function norm 0.432006
#   3 SNES Function norm 0.00119107
# Nonlinear Poisson_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 3
#   0 SNES Function norm 81.6459
#   1 SNES Function norm 16.6908
#   2 SNES Function norm 0.744868
#   3 SNES Function norm 0.00366806
# Nonlinear Poisson_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 3
#   0 SNES Function norm 85.5744
#   1 SNES Function norm 20.4477
#   2 SNES Function norm 1.17852
#   3 SNES Function norm 0.00927702
#   4 SNES Function norm 1.22638e-06
# Nonlinear Poisson_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 4
#   0 SNES Function norm 89.5046
#   1 SNES Function norm 24.5352
#   2 SNES Function norm 1.75081
#   3 SNES Function norm 0.0203114
#   4 SNES Function norm 2.7798e-06
# Nonlinear Poisson_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 4
#   0 SNES Function norm 93.4361
#   1 SNES Function norm 28.9924
#   2 SNES Function norm 2.4791
#   3 SNES Function norm 0.039893
#   4 SNES Function norm 6.40594e-06
# Nonlinear Poisson_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 4
#   0 SNES Function norm 97.3689
#   1 SNES Function norm 33.8677
#   2 SNES Function norm 3.38039
#   3 SNES Function norm 0.0719335
#   4 SNES Function norm 1.59507e-05
# Nonlinear Poisson_1_ solve converged due to CONVERGED_FNORM_RELATIVE iterations 4

# %% [markdown]
# Evaluate our numerical solution and plot it

# %%
with mesh.access():    
    mesh_numerical_soln = uw.function.evaluate(poisson_solver.u.fn, mesh.data, mesh.N)

# %%
if MPI.COMM_WORLD.size == 1:
    import numpy as np
    import pyvista as pv
    import vtk
    pv.global_theme.background = "white"
    pv.global_theme.window_size = [500, 500]
    pv.global_theme.antialiasing = True
    pv.global_theme.jupyter_backend = "panel"
    pv.global_theme.smooth_shading = True
    mesh.vtk("mesh_tmp.vtk")
    pvmesh = pv.read("mesh_tmp.vtk")
    with mesh.access():
        pvmesh.point_data["2DannulusAnalytic"] = mesh_numerical_soln
    pl = pv.Plotter()
    pl.add_mesh(
        pvmesh,
        cmap="coolwarm",
        edge_color="Black",
        show_edges=True,
        scalars="2DannulusAnalytic",
        use_transparency=False,
        opacity=0.5,
    )
    pl.camera_position = "xy"
    pl.show(cpos="xy")
    # pl.screenshot(filename="test.png")
# Out:
# /Users/maxwilliams/anaconda3/envs/uw3/lib/python3.10/site-packages/pyvista/themes.py:2577: PyVistaDeprecationWarning: antialising is deprecated.  Please use `anti_aliasing` instead.
#   warnings.warn(
# /Users/maxwilliams/anaconda3/envs/uw3/lib/python3.10/site-packages/pyvista/themes.py:2545: PyVistaDeprecationWarning: `anti_aliasing` is now a string or None and must be either "ssaa", "msaa", "fxaa", or None
#   warnings.warn(
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d4b197bb-92ff-4400-8af6-d32336533e14'>
#   <div id="d32a0903-0c06-4ae8-845a-6a2e26ef2281" data-root-id="d4b197bb-92ff-4400-8af6-d32336533e14" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"06286659-e8af-4dcd-9b59-77ace215aa89":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"d4b197bb-92ff-4400-8af6-d32336533e14"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"7af2536e-aa0c-4ead-a480-8c929c6921e9","attributes":{"plot_id":"d4b197bb-92ff-4400-8af6-d32336533e14","comm_id":"553d95bc695548278cea19a8985d7e9e","client_comm_id":"682130879d954c0587d131ad6f5f23a5"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"06286659-e8af-4dcd-9b59-77ace215aa89","roots":{"d4b197bb-92ff-4400-8af6-d32336533e14":"d32a0903-0c06-4ae8-845a-6a2e26ef2281"},"root_ids":["d4b197bb-92ff-4400-8af6-d32336533e14"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['vtk'] !== undefined) && ( root['vtk'] !== undefined) && ( root['vtk'] !== undefined) && ( root['vtk'] !== undefined) && ( root['vtk'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# /var/folders/s9/rd03rq4x0px79z1jnyqlz3540000gn/T/ipykernel_92222/3739753604.py:8: PyVistaDeprecationWarning: `panel` backend is deprecated and is planned for future removal.
#   pv.global_theme.jupyter_backend = "panel"
# WARNING:param.VTKRenderWindowSynchronized: Providing a width-responsive sizing_mode ('stretch_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# WARNING:param.Row: Providing a width-responsive sizing_mode ('stretch_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# BokehModel(combine_events=True, render_bundle={'docs_json': {'48edb0ad-3a2d-4b2d-8b45-c26ae0df91d0': {'version…
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# The analytic solution is $\phi = x^2 + y^2$. Evaluate it and plot it.

# %%
x, y = mesh.X  ## access the symbolic representations of the coordinates
analytic_fn = x**2 + y**2  ## the analytic solution

# %%
with mesh.access():
    mesh_analytic_soln = uw.function.evaluate(analytic_fn, mesh.data, mesh.N)

# %%
if MPI.COMM_WORLD.size == 1:
    import numpy as np
    import pyvista as pv
    import vtk
    pv.global_theme.background = "white"
    pv.global_theme.window_size = [500, 500]
    pv.global_theme.antialiasing = True
    pv.global_theme.jupyter_backend = "panel"
    pv.global_theme.smooth_shading = True
    mesh.vtk("mesh_tmp.vtk")
    pvmesh = pv.read("mesh_tmp.vtk")
    with mesh.access():
        pvmesh.point_data["2DannulusAnalytic"] = mesh_analytic_soln
    pl = pv.Plotter()
    pl.add_mesh(
        pvmesh,
        cmap="coolwarm",
        edge_color="Black",
        show_edges=True,
        scalars="2DannulusAnalytic",
        use_transparency=False,
        opacity=0.5,
    )
    pl.camera_position = "xy"
    pl.show(cpos="xy")
    # pl.screenshot(filename="test.png")
# Out:
# /Users/maxwilliams/anaconda3/envs/uw3/lib/python3.10/site-packages/pyvista/themes.py:2577: PyVistaDeprecationWarning: antialising is deprecated.  Please use `anti_aliasing` instead.
#   warnings.warn(
# /Users/maxwilliams/anaconda3/envs/uw3/lib/python3.10/site-packages/pyvista/themes.py:2545: PyVistaDeprecationWarning: `anti_aliasing` is now a string or None and must be either "ssaa", "msaa", "fxaa", or None
#   warnings.warn(
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='194416ea-116b-475d-9488-6a9f1240fad0'>
#   <div id="a162c356-6abc-424a-91c7-dceb9b36b590" data-root-id="194416ea-116b-475d-9488-6a9f1240fad0" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"85e10273-7f0e-408a-ab1f-a6a7d2e78534":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"194416ea-116b-475d-9488-6a9f1240fad0"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"a41c9e7f-4007-4e7c-bc19-fe18ff93ac6c","attributes":{"plot_id":"194416ea-116b-475d-9488-6a9f1240fad0","comm_id":"7385a762dd144657a672d9646f56ad90","client_comm_id":"8f6a0a163ac34ac593710906ff805681"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"85e10273-7f0e-408a-ab1f-a6a7d2e78534","roots":{"194416ea-116b-475d-9488-6a9f1240fad0":"a162c356-6abc-424a-91c7-dceb9b36b590"},"root_ids":["194416ea-116b-475d-9488-6a9f1240fad0"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['vtk'] !== undefined) && ( root['vtk'] !== undefined) && ( root['vtk'] !== undefined) && ( root['vtk'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# /var/folders/s9/rd03rq4x0px79z1jnyqlz3540000gn/T/ipykernel_92222/3329395479.py:8: PyVistaDeprecationWarning: `panel` backend is deprecated and is planned for future removal.
#   pv.global_theme.jupyter_backend = "panel"
# WARNING:param.VTKRenderWindowSynchronized: Providing a width-responsive sizing_mode ('stretch_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# WARNING:param.Row: Providing a width-responsive sizing_mode ('stretch_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# BokehModel(combine_events=True, render_bundle={'docs_json': {'0c535a98-6a88-4fb1-827d-43429e3694df': {'version…
